# %%
from pylab import *
from frostsynth.sampling import *
from frostsynth.noise import *
from frostsynth.ipython import *
from frostsynth.analysis import *

# %%
set_sample_rate(44100)

# %%
t = trange(10)

# %%
plot(t, linsnow(t + 2))

# %%
Audio(linsnow(220 + t * 1000, 0.5) * 0.5, autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot(np.convolve(abs(rfft(linsnow(np.full(100000, 3000)))), np.ones(100)))
