# %%
from pylab import *
from frostsynth.sampling import *
from frostsynth.noise import *
from frostsynth.ipython import *
from frostsynth.analysis import *

# %%
set_sample_rate(44100)

# %%
t = trange(10)

# %%
plot(t, linsnow(t + 2))

# %%
Audio(linsnow(440 + t * 1000, t * 0.1) * 0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2ad0b4b35eff> in <module>()
# ----> 1 Audio(linsnow(440 + t * 1000, t * 0.1) * 0.5)
#
# /home/lumi/Python/frostsynth2/frostsynth/sampling.pyc in wrapper(*args, **kwargs)
#      22         if SAMPLE_RATE is None:
#      23             raise ValueError("Cannot call sampling function without setting sample rate first.")
# ---> 24         result = f(*args, **kwargs)
#      25         SAMPLE_RATE = old_rate
#      26         return result
#
# /home/lumi/Python/frostsynth2/frostsynth/noise.py in linsnow(frequency, variation)
#      63     total_samples = int(np.ceil(phase[-1]))
#      64     xp = np.arange(total_samples, dtype=float)
# ---> 65     xp += variation * (np.random.rand(total_samples) - np.random.rand(total_samples))
#      66     fp = np.random.rand(total_samples) * 2 - 1
#      67     return np.interp(phase, xp, fp)
#
# ValueError: operands could not be broadcast together with shapes (441000,) (54400,)
