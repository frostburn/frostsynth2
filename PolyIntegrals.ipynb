# %%
from pylab import *
from frostsynth.waveform.poly_integrals import *

# %%
t = linspace(0, 2, 1000)

# %%
plot(saw(t))

# %%
plot(par(t))

# %%
plot(par0(t))

# %%
plot(cub(t))

# %%
plot(qua(t))

# %%
plot(qua0(t))
