# %%
# %matplotlib inline
from pylab import *
from frostsynth.ipython import *
from frostsynth.waveform import *
from frostsynth.sampling import *
from frostsynth.note import *
import numpy as np
from frostsynth.instrument import *
import scipy.signal

# %%
set_sample_rate(44100)

# %%
kick = Kick();kick
# Out:
# VBox(children=(Label(value=u'Kick drum'), FloatSlider(value=10.0, description=u'frequency', max=50.0, min=1.0, step=1.0), FloatSlider(value=2.0, description=u'attack', max=6.0, min=0.5), FloatSlider(value=0.1, description=u'meekness', max=0.5, min=0.01, step=0.01), FloatSlider(value=20.0, description=u'decay', max=60.0, step=1.0), FloatSlider(value=1.0, description=u'distortion', max=5.0, min=0.5, step=0.5), FloatSlider(value=1.5, description=u'noise', max=5.0, step=0.5)))

# %%
kick.preview()
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
snare = Snare();snare
# Out:
# VBox(children=(Label(value=u'Snare'), FloatSlider(value=1.0, description=u'detune', max=1.2, min=0.8, step=0.01), FloatSlider(value=1.0, description=u'decay', max=2.0, min=0.5), FloatSlider(value=15.0, description=u'distortion', max=50.0, min=0.1), FloatSlider(value=5.0, description=u'noise volume', max=10.0, step=0.5), FloatSlider(value=16.0, description=u'noise decay', max=30.0, min=4.0, step=1.0)))

# %%
snare.preview()
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot(kick.play(NonPitched()))

# %%
plot(snare.play(NonPitched()))
