# %%
from frostsynth.ipython import *
from frostsynth.waveform import *
from frostsynth.sampling import *
from frostsynth.pitch import *
from frostsynth.scale import *
from frostsynth.instrument import *

# %%
set_sample_rate(44100)
t = trange(0, 3)

# %%
Audio(0.4 * lissajous23(220 * t, 0.8 * sine(t), cosine(7 * t)), autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tg = ToggleGrid(3, 2)

# %%
tg

# %%
tg[1,2] = True;tg[0,1] = True

# %%
tg.value
# Out:
# array([[False, False],
#        [ True, False],
#        [False,  True]])

# %%
tg.value = [[0, 0],[1,1],[1,0]]

# %%
roll = NoteGrid(8, minor(), beats_per_bar=4)

# %%
roll[0, 0] = 1;roll[1, 2] = 1;roll[3, 7] = 1;roll[4, 4] = 1

# %%
roll

# %%
bass = SawBass();bass

# %%
Audio(0.5 * bass.play_sheet(roll.sheet.transpose(-20) * 2), autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
roll = ChromaticGrid(12, beats_per_bar=6)

# %%
roll

# %%
Audio(0.5 * bass.play_sheet(roll.sheet.transpose(-10)), autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
