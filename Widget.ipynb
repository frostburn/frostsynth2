# %%
from frostsynth.ipython import *
from frostsynth.waveform import *
from frostsynth.sampling import *
from frostsynth.pitch import *
from frostsynth.scale import *

# %%
set_sample_rate(44100)
t = trange(0, 3)

# %%
Audio(0.5 * lissajous23(220 * t, 0.8 * sine(t), cosine(7 * t)), autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
t = ToggleGrid(3, 2)

# %%
t

# %%
t[1,2] = True;t[0,1] = True

# %%
t.value
# Out:
# array([[False, False],
#        [ True, False],
#        [False,  True]])

# %%
t.value = [[0, 0],[1,1],[1,0]]

# %%
roll = InstrumentGrid(8, 0.3, lambda p: 0.8 * par0(mtof(p) * trange(0.2)), minor())

# %%
roll[0, 0] = 1;roll[1, 2] = 1;roll[3, 7] = 1

# %%
roll

# %%
roll.display(autoplay=False, sample_rate=11025)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
