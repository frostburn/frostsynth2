# %%
from pylab import *
from frostsynth.waveform import *

# %%
t = linspace(-0.1, 1.1, 1000)

# %%
plot(sine(t))

# %%
plot(cosine(t))

# %%
plot(softsaw(t, 0.5))

# %%
plot(softsaw(4 * t, t))

# %%
plot(softarc(t, 0.5))

# %%
plot(softarc(4 * t, t))
